# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.grid_2d_graph(m=5, n=5)
pos = nx.nx_pydot.graphviz_layout(G, prog='dot')

plt.figure(figsize=(5, 5))
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
plt.axis('off')
plt.savefig('e1.png')

# %%
G = nx.grid_2d_graph(m=3, n=3)
pos = nx.nx_pydot.graphviz_layout(G, prog='dot')

plt.figure(figsize=(5, 5))
nodes = nx.draw_networkx_nodes(G, pos, node_size=600, node_color=['w', 'b', 'w', 'b', 'r', 'b', 'w', 'b', 'w'])
nodes.set_edgecolor('k')
nx.draw_networkx_edges(G, pos)
plt.axis('off')
plt.savefig('e1_colour.png')

# %%
G.nodes()
# Out:
# NodeView(((0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2), (2, 0), (2, 1), (2, 2)))

# %%
G = nx.triangular_lattice_graph(m=5, n=4)
pos = nx.nx_pydot.graphviz_layout(G, prog='sfdp')

plt.figure(figsize=(5, 5))
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
plt.axis('off')
plt.savefig('e2.png')

# %%
G = nx.hexagonal_lattice_graph(m=3, n=2)
pos = nx.nx_pydot.graphviz_layout(G, prog='sfdp')

plt.figure(figsize=(5, 5))
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
plt.axis('off')
plt.savefig('e3.png')

# %%
G = nx.Graph([(i, i+1) for i in range(4)])
pos = nx.nx_pydot.graphviz_layout(G, prog='dot')

plt.figure(figsize=(5, 5))
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
plt.axis('off')
plt.savefig('e4.png')
